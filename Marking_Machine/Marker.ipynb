# %%
import Read_question
import Grade
from IPython.display import display, Math
Q_no = "Q1.question"
Q = Read_question.get_question(Q_no)
Question = Q[0]
True_Answer = Q[1]
print(Question)
print(f"----------------------------------------------------------")
print("Enter your answer in LaTeX format. Separate each row with a comma ( , ).")
print("Example: [ax^2 + bx + c = 0, x^2 + (b/a)x + (c/a) = 0, x² + (b/a)x = −c/a] ")


while True:
    user_Answers = input("Your Answer: ")
    user_Answers = Read_question.string_to_list(user_Answers)
    for Answer in user_Answers:
        display(Math(Answer))
    True_flag_user = input("Confirm ? y/n ")
    if True_flag_user == "y":
        break
    if True_flag_user == "Y":
        break


total_mark = 2
print("Model ans is the following:")
for Answer in True_Answer:
        display(Math(Answer))

Grade = Grade.grade_answer(Question,True_Answer,user_Answers,total_mark)
print(f"Report {Grade[0]} ")
print(f"-------------------------------------------")
print(f"Total mark is {Grade[1]} ")
# Out:
# A 63 W immersion heater is used to keep the water in a large beaker boiling under standard atmospheric pressure. In 6 minutes, 8 g of water boils away. Neglect any heat loss to surroundings.
#
# 	Find the specific latent heat of vaporization of water, l.
# ----------------------------------------------------------
# Enter your answer in LaTeX format. Separate each row with a comma ( , ).
# Example: [ax^2 + bx + c = 0, x^2 + (b/a)x + (c/a) = 0, x² + (b/a)x = −c/a]
# Your Answer:  [a = bc , abcd = 20 ,p = 15]
# $\displaystyle a = bc$
# $\displaystyle abcd = 20$
# $\displaystyle p = 15$
# Confirm ? y/n  Y
# Model ans is the following:
# $\displaystyle Pt = ml$
# $\displaystyle l = \frac{63 \times ( 6 \times 60)}{ 8/1000 }$
# $\displaystyle l = 2835000Jkg^{-1}$
# Report # Marking Report
#
# **Final mark: 0 / 2**
#
# ## Criterion-by-criterion marking
#
# 1. [Correctly identifying the power-time product as the energy supplied]
#    • Awarded: 0 / 1 (M)
# ...
